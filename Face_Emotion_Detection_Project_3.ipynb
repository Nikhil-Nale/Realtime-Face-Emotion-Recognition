# %%
import cv2
from google.colab import files

# %%
# !pip install deepface
from deepface import DeepFace

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3e5cf364-9bc4-4f41-9d49-c079fc01c380" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3e5cf364-9bc4-4f41-9d49-c079fc01c380">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving happyboy.jpg to happyboy (1).jpg

# %%
img = cv2.imread('happyboy.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img) # BGR

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
prediction = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:04<00:00,  1.23s/it]

# %%
prediction
# Out:
# {'age': 30,
#  'dominant_emotion': 'happy',
#  'dominant_race': 'white',
#  'emotion': {'angry': 0.00012831490783492736,
#   'disgust': 5.522937559486846e-08,
#   'fear': 0.882627896055234,
#   'happy': 99.06306874000207,
#   'neutral': 0.05155002549439365,
#   'sad': 0.0013012201902224362,
#   'surprise': 0.0013214139715270249},
#  'gender': 'Man',
#  'race': {'asian': 0.10505105513470708,
#   'black': 0.003288490524001618,
#   'indian': 0.03566323587215115,
#   'latino hispanic': 8.510633288546408,
#   'middle eastern': 2.5053717934642084,
#   'white': 88.83998527050194}}

# %%
type(prediction)
# Out:
# dict

# %%
prediction["dominant_emotion"]
# Out:
# 'happy'

# %% [markdown]
# # We are trying to draw a Rectangle across the face

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        # print (facecascade.empty())
faces = faceCascade.detectMultiScale(gray, 1.1, 4)
        # Draw a rectangle around the faces
for (x, y, w, h) in faces:
  cv2.rectangle(img, (x,y), (x+w, y+h), (0, 255, 0), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
# i want to text on image

font = cv2.FONT_HERSHEY_SIMPLEX       # This is my font type

         # use putText() method for inserting test on image
cv2.putText(img, 
            prediction['dominant_emotion'], 
            (0,50),  # offset 
            font, 2,
            (0, 0, 255),
            2,
            cv2.LINE_4) ;

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
